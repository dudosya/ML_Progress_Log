# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
# generate X axis independent points
X = torch.arange(-5,5,0.1).view(-1,1)
# random number
some_random_slope_scalar = 3
#generate linear function
Y_no_noise = some_random_slope_scalar*X

#plot
plt.plot(X,Y_no_noise)
plt.grid()
plt.title("Linear function without noise")
# Out:
# Text(0.5, 1.0, 'Linear function without noise')

# %%
# additive noise is added (Normal Distribution)

bias = -2
Y = Y_no_noise + torch.randn(X.size())+bias

#plot
plt.plot(X,Y)
plt.grid()
plt.title("Linear function with noise")
# Out:
# Text(0.5, 1.0, 'Linear function with noise')

# %%
# forward pass = prediction
def forward(x):
    return w*x+b

# %%
#MSE loss functions ['/2' is there for easier differentiation]
def loss_fn(y_hat,y):
    return torch.mean((y_hat-y)**2/2)

# %%
#some random initialization of two variables. weight and bias
w = torch.tensor(-10.0, requires_grad=True)
b = torch.tensor(-20.0, requires_grad=True)

# %%
lr = 0.1 #learning rate
loss_list = [] #empty list to store loss
iter = 30 # no. of iters per epoch = 30

# %%
#training loop
print('Index \tLoss \t\t\tWeight (slope) \t\tBias (y-intercept) ')
for i in range(iter):
    Y_pred = forward(X) #predicted outputs shape = [100,1]
    loss = loss_fn(Y_pred,Y) # MSE loss calculated
    loss_list.append(loss.item()) # stored in a list
    loss.backward() #backpropagation 
    # calculates gradients of loss w.r.t. parameters (weight and bias)
    w.data = w.data - lr*w.grad.data # weight changes incrementally
    b.data = b.data - lr*b.grad.data # same thing with bias
    w.grad.data.zero_() # pytorch does not automatically clear the gradient
    b.grad.data.zero_() # so have to do that ourselves
    
    # some printing
    print('{}, \t{}, \t{}, \t{}'.format(i, loss.item(), w.item(), b.item()))
# Out:
# Index 	Loss 			Weight (slope) 		Bias (y-intercept)
# 0, 	854.1781005859375, 	0.7312994003295898, 	-18.260271072387695
# 1, 	152.81614685058594, 	2.526759147644043, 	-16.640859603881836
# 2, 	108.95500183105469, 	2.8338003158569336, 	-15.17441177368164
# 3, 	87.95316314697266, 	2.8922548294067383, 	-13.853074073791504
# 4, 	71.34300231933594, 	2.9085941314697266, 	-12.66357707977295
# 5, 	57.898902893066406, 	2.917262077331543, 	-11.592948913574219
# 6, 	47.008670806884766, 	2.924058437347412, 	-10.629340171813965
# 7, 	38.186920166015625, 	2.9300081729888916, 	-9.76205825805664
# 8, 	31.040761947631836, 	2.935335159301758, 	-8.981473922729492
# 9, 	25.251928329467773, 	2.940124988555908, 	-8.278922080993652
# 10, 	20.562623977661133, 	2.9444353580474854, 	-7.64660120010376
# 11, 	16.76399803161621, 	2.948314666748047, 	-7.07749080657959
# 12, 	13.686877250671387, 	2.95180606842041, 	-6.565272331237793
# 13, 	11.194222450256348, 	2.9549484252929688, 	-6.104258060455322
# 14, 	9.175018310546875, 	2.9577767848968506, 	-5.689329624176025
# 15, 	7.539339065551758, 	2.960322380065918, 	-5.315879821777344
# 16, 	6.214338779449463, 	2.962613344192505, 	-4.979762077331543
# 17, 	5.1410064697265625, 	2.9646754264831543, 	-4.677244663238525
# 18, 	4.271541118621826, 	2.966531276702881, 	-4.404968738555908
# 19, 	3.567221164703369, 	2.9682016372680664, 	-4.159911155700684
# 20, 	2.9966790676116943, 	2.969705104827881, 	-3.9393510818481445
# 21, 	2.5345053672790527, 	2.9710581302642822, 	-3.7408394813537598
# 22, 	2.160116195678711, 	2.972275972366333, 	-3.5621721744537354
# 23, 	1.856837511062622, 	2.973372220993042, 	-3.4013655185699463
# 24, 	1.6111633777618408, 	2.9743587970733643, 	-3.25663423538208
# 25, 	1.4121525287628174, 	2.9752466678619385, 	-3.126371145248413
# 26, 	1.2509417533874512, 	2.976045846939087, 	-3.009129762649536
# 27, 	1.1203505992889404, 	2.9767651557922363, 	-2.903608560562134
# 28, 	1.014563798904419, 	2.977412462234497, 	-2.808635950088501
# 29, 	0.9288702607154846, 	2.9779951572418213, 	-2.7231574058532715

# %%
#some plotting script
plt.plot(loss_list), plt.grid()
plt.xlabel("Epochs/Iterations")
plt.ylabel("Loss")
plt.show()
